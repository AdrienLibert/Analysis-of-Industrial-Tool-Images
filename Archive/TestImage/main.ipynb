# %%
import nbimporter
import pandas as pd
from tooth_pattern import draw_tooth_pattern
from list_pas_diam import pattern_list
from tooth_pattern import match
from droite_normale import match_and_draw_normal_and_analyze
from droite_normale import extract_line_pixels
from droite_normale import diameter_filtage
import cv2
# Out:
# C:\Users\adrie\AppData\Local\Temp\ipykernel_19940\2131052313.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 import nbimporter
#       2 import pandas as pd
# ----> 3 from tooth_pattern import draw_tooth_pattern
#       4 from list_pas_diam import pattern_list
#       5 from tooth_pattern import match
#
# File ~\OneDrive\Bureau\Analysis-of-Industrial-Tool-Images\SRC\tooth_pattern.py:49
#      45         pattern_image = cv2.rotate(pattern_image, cv2.ROTATE_180)
#      47     return pattern_image
# ---> 49 pattern_image = draw_tooth_pattern(pas_reel_mm,reference_object_mm,image_path,True)
#      50 cv2.imwrite('pattern_image.jpg', pattern_image)
#      52 def match(template,img_path):
#
# File ~\OneDrive\Bureau\Analysis-of-Industrial-Tool-Images\SRC\tooth_pattern.py:19, in draw_tooth_pattern(pas_reel_mm, reference_object_mm, image_path, rotation)
#      18 def draw_tooth_pattern(pas_reel_mm, reference_object_mm, image_path, rotation):
# ---> 19     size_pixels = conversion_piece(image_path, reference_object_mm)
#      21     pas_pixels = pas_reel_mm / size_pixels
#      23     tooth_height = max(int(1 / size_pixels), 1)
#
# File ~\OneDrive\Bureau\Analysis-of-Industrial-Tool-Images\SRC\diametre_monnaie.ipynb:4, in conversion_piece(image_path, taille_piece)
#       1 {
#       2  "cells": [
#       3   {
# ----> 4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "74e0480f",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import cv2 \n",
#      11     "import numpy as np"
#      12    ]
#      13   },
#      14   {
#      15    "cell_type": "markdown",
#      16    "id": "1760719e",
#      17    "metadata": {},
#      18    "source": [
#      19     "Fonction pour le diamètre de la pièce de monnaie"
#      20    ]
#      21   },
#      22   {
#      23    "cell_type": "code",
#      24    "execution_count": 2,
#      25    "id": "42c6b057",
#      26    "metadata": {},
#      27    "outputs": [],
#      28    "source": [
#      29     "def conversion_piece(image_path,taille_piece):\n",
#      30     "    image = cv2.imread(image_path)#charge image\n",
#      31     "    if image is None:\n",
#      32     "        raise ValueError(\"L'image n'a pas pu être chargée.\")\n",
#      33     "    \n",
#      34     "    taille_noyau = (5, 5)\n",
#      35     "    sigma = 0\n",
#      36     "    blurred_image = cv2.GaussianBlur(image, taille_noyau, sigma)\n",
#      37     "    \n",
#      38     "    \n",
#      39     "    gray = cv2.cvtColor(blurred_image, cv2.COLOR_BGR2GRAY)\n",
#      40     "    _,thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)\n",
#      41     "    thresh = cv2.bitwise_not(thresh)\n",
#      42     "\n",
#      43     "    element = cv2.getStructuringElement(shape=cv2.MORPH_RECT, ksize=(5, 5))\n",
#      44     "\n",
#      45     "    morph_img = thresh.copy()\n",
#      46     "    cv2.morphologyEx(src=thresh, op=cv2.MORPH_CLOSE, kernel=element, dst=morph_img)\n",
#      47     "\n",
#      48     "    contours,_ = cv2.findContours(morph_img,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE) #trouver les contours\n",
#      49     "\n",
#      50     "    output_image = cv2.cvtColor(morph_img, cv2.COLOR_GRAY2BGR)# préparer l'image de sortie\n",
#      51     "\n",
#      52     "    height, width = morph_img.shape[:2]# dimensions de l'image\n",
#      53     "\n",
#      54     "    y_limit1 = height - 800 #limite\n",
#      55     "    y_limit2 = 800\n",
#      56     "\n",
#      57     "    max_contour = None #contour et aire\n",
#      58     "    max_area = 0\n",
#      59     "\n",
#      60     "    for cnt in contours: #on cherche dans la zone les contours\n",
#      61     "        (x, y), radius = cv2.minEnclosingCircle(cnt)\n",
#      62     "        center = (int(x), int(y))\n",
#      63     "        if (center[1] > y_limit1 or center[1] < y_limit2):\n",
#      64     "            area = cv2.contourArea(cnt)\n",
#      65     "            if area > max_area:\n",
#      66     "                max_area = area\n",
#      67     "                max_contour = cnt\n",
#      68     "                \n",
#      69     "    if max_contour is not None:\n",
#      70     "        (x, y), radius = cv2.minEnclosingCircle(max_contour)\n",
#      71     "        diameter = 2 * int(radius)\n",
#      72     "    else:\n",
#      73     "        diameter = 0\n",
#      74     "\n",
#      75     "    return taille_piece/diameter #diametre"
#      76    ]
#      77   },
#      78   {
#      79    "cell_type": "markdown",
#      80    "id": "61abe7f9",
#      81    "metadata": {},
#      82    "source": [
#      83     "Brouillon test des fonctions OpenCV pour la pièce de monnaie"
#      84    ]
#      85   },
#      86   {
#      87    "cell_type": "code",
#      88    "execution_count": 3,
#      89    "id": "c234d801",
#      90    "metadata": {},
#      91    "outputs": [
#      92     {
#      93      "name": "stdout",
#      94      "output_type": "stream",
#      95      "text": [
#      96       "Estimated in pixels: 0.005937992643194956\n"
#      97      ]
#      98     }
#      99    ],
#     100    "source": [
#     101     "image_path = '../DataBase/test1.jpg'\n",
#     102     "conversion = conversion_piece(image_path,22.6)\n",
#     103     "print(f\"Estimated in pixels: {conversion}\")"
#     104    ]
#     105   },
#     106   {
#     107    "cell_type": "code",
#     108    "execution_count": 4,
#     109    "id": "1d51effe",
#     110    "metadata": {},
#     111    "outputs": [],
#     112    "source": [
#     113     "image_path = '../DataBase/image3.jpg'\n",
#     114     "image = cv2.imread(image_path)"
#     115    ]
#     116   },
#     117   {
#     118    "cell_type": "code",
#     119    "execution_count": 4,
#     120    "id": "5634d5f3",
#     121    "metadata": {},
#     122    "outputs": [
#     123     {
#     124      "ename": "NameError",
#     125      "evalue": "name 'image' is not defined",
#     126      "output_type": "error",
#     127      "traceback": [
#     128       "\u001b---------------------------------------------------------------------------\u001b",
#     129       "\u001bNameError\u001b                                 Traceback (most recent call last)",
#     130       "Cell \u001bIn[4], line 3\u001b\n\u001b      1\u001b taille_noyau \u001b=\u001b (\u001b5\u001b, \u001b5\u001b)\n\u001b      2\u001b sigma \u001b=\u001b \u001b0\u001b\n\u001b----> 3\u001b image \u001b=\u001b cv2\u001b.\u001bGaussianBlur(image, taille_noyau, sigma)\n\u001b      5\u001b gray_image \u001b=\u001b cv2\u001b.\u001bcvtColor(image, cv2\u001b.\u001bCOLOR_BGR2GRAY)\n\u001b      6\u001b th \u001b=\u001b cv2\u001b.\u001badaptiveThreshold(gray_image,\u001b255\u001b,cv2\u001b.\u001bADAPTIVE_THRESH_GAUSSIAN_C,cv2\u001b.\u001bTHRESH_BINARY,\u001b71\u001b,\u001b17\u001b)\n",
#     131       "\u001bNameError\u001b: name 'image' is not defined"
#     132      ]
#     133     }
#     134    ],
#     135    "source": [
#     136     "taille_noyau = (5, 5)\n",
#     137     "sigma = 0\n",
#     138     "image = cv2.GaussianBlur(image, taille_noyau, sigma)\n",
#     139     "\n",
#     140     "gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)\n",
#     141     "th = cv2.adaptiveThreshold(gray_image,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,71,17)\n",
#     142     "edges = cv2.adaptiveThreshold(th, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 3, 2)"
#     143    ]
#     144   },
#     145   {
#     146    "cell_type": "code",
#     147    "execution_count": null,
#     148    "id": "b46efae1",
#     149    "metadata": {},
#     150    "outputs": [],
#     151    "source": [
#     152     "contours, hierarchy = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)\n",
#     153     "\n",
#     154     "output_image = cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)"
#     155    ]
#     156   },
#     157   {
#     158    "cell_type": "code",
#     159    "execution_count": 1,
#     160    "id": "8758ac04",
#     161    "metadata": {},
#     162    "outputs": [
#     163     {
#     164      "ename": "NameError",
#     165      "evalue": "name 'edges' is not defined",
#     166      "output_type": "error",
#     167      "traceback": [
#     168       "\u001b---------------------------------------------------------------------------\u001b",
#     169       "\u001bNameError\u001b                                 Traceback (most recent call last)",
#     170       "Cell \u001bIn[1], line 1\u001b\n\u001b----> 1\u001b height \u001b=\u001b edges\u001b.\u001bshape[\u001b0\u001b[39m]\n\u001b      2\u001b width \u001b=\u001b edges\u001b.\u001bshape[\u001b1\u001b[39m]\n\u001b      4\u001b x_limit \u001b=\u001b width\n",
#     171       "\u001bNameError\u001b: name 'edges' is not defined"
#     172      ]
#     173     }
#     174    ],
#     175    "source": [
#     176     "height = edges.shape[0]\n",
#     177     "width = edges.shape[1]\n",
#     178     "\n",
#     179     "x_limit = width\n",
#     180     "y_limit = height - 800\n",
#     181     "top_left = (0, y_limit)\n",
#     182     "bottom_right = (x_limit, height)\n",
#     183     "cv2.rectangle(output_image, top_left, bottom_right, (255, 0, 0), 2)\n",
#     184     "\n",
#     185     "y_limit2 = 800\n",
#     186     "top_left2 = (0, 0)\n",
#     187     "bottom_right2 = (x_limit, y_limit2)\n",
#     188     "cv2.rectangle(output_image, top_left2, bottom_right2, (255, 0, 0), 2)\n",
#     189     "\n",
#     190     "max_contour = None\n",
#     191     "max_area = 0\n",
#     192     "\n",
#     193     "for cnt in contours:\n",
#     194     "    (x, y), radius = cv2.minEnclosingCircle(cnt)\n",
#     195     "    center = (int(x), int(y))\n",
#     196     "    radius = int(radius)\n",
#     197     "    if (center[1] > y_limit or center[1] < y_limit2):\n",
#     198     "        area = cv2.contourArea(cnt)\n",
#     199     "        if area > max_area:\n",
#     200     "            max_area = area\n",
#     201     "            max_contour = cnt\n",
#     202     "            \n",
#     203     "if max_contour is not None:\n",
#     204     "    (x, y), radius = cv2.minEnclosingCircle(max_contour)\n",
#     205     "    center = (int(x), int(y))\n",
#     206     "    radius = int(radius)\n",
#     207     "    diameter = 2 * radius\n",
#     208     "    cv2.circle(output_image, center, radius, (0, 255, 0), 2)\n",
#     209     "    cv2.circle(output_image, center, 1, (0, 0, 255), 3)\n",
#     210     "    start_point = (int(x - radius), int(y))\n",
#     211     "    end_point = (int(x + radius), int(y))\n",
#     212     "    cv2.line(output_image, start_point, end_point, (255, 0, 0), 2)\n",
#     213     "\n",
#     214     "cv2.imwrite('output_image_test.png', output_image)\n",
#     215     "print(f\"Estimated diameter in pixels: {diameter}\")"
#     216    ]
#     217   },
#     218   {
#     219    "cell_type": "code",
#     220    "execution_count": null,
#     221    "id": "650af6e9",
#     222    "metadata": {},
#     223    "outputs": [],
#     224    "source": []
#     225   }
#     226  ],
#     227  "metadata": {
#     228   "kernelspec": {
#     229    "display_name": "Python 3 (ipykernel)",
#     230    "language": "python",
#     231    "name": "python3"
#     232   },
#     233   "language_info": {
#     234    "codemirror_mode": {
#     235     "name": "ipython",
#     236     "version": 3
#     237    },
#     238    "file_extension": ".py",
#     239    "mimetype": "text/x-python",
#     240    "name": "python",
#     241    "nbconvert_exporter": "python",
#     242    "pygments_lexer": "ipython3",
#     243    "version": "3.11.5"
#     244   }
#     245  },
#     246  "nbformat": 4,
#     247  "nbformat_minor": 5
#     248 }
#
# ValueError: L'image n'a pas pu être chargée.

# %%
def main(image_path,reference_object_mm,longueur_cm,depassement_mm):
    l = pattern_list(pd.read_csv('TableauConversion/Metrique.csv'))
    l_seuil = []
    seuil = 0
    i_final = None
    for i in l:
        # if i[0] == 9.72:
        #     pass
        pas_reel_mm = 25.4 / i[1] #pas réel du filetage en mm
        template_tmp = draw_tooth_pattern(image_path,i[0],pas_reel_mm,reference_object_mm,False)
        match_tmp = match(template_tmp,image_path)
        l_seuil.append((i,match_tmp[2]))
        if match_tmp[2] > seuil: #on recup le meilleur seuil
            seuil = match_tmp[2]
            i_final = match_tmp[0]
            res = (i[0],0)
    #regarder le diametre
    # l_seuil_sort = sorted(l_seuil, key=lambda l: l[1])
    # print(l_seuil_sort)
    return i_final, res

# %%
image_path = '.../DataBase/image10.jpg' 
reference_object_mm = 24.25
depassement_mm = 0.2
longueur_cm = 10

# %%
#TEST 

#Image 10 - 16 mm de diametre - 13 mm de pas - 24.25 piece de 50 centime
#Image 9 - 16 mm de diametre - 13 mm de pas - 24.25 piece de 50 centime
#Image 7 -  20 mm de diametre - 14 mm de pas - 22.6 piece de 100 yen
#Image 11 -  10 mm de diametre - 16 mm de pas - 24.25 piece de 50 centime

#Image 7 - res = (4.16, 32.0) FAUX
#Image 10 - res = (4.76, 24.0) FAUX

#Image 7 - res = (9.72, 2.0) FAUX
#Image 9 - res = (9.72, 2.0) FAUX
#Image 10 - res = (9.72, 2.0) FAUX
#Image 11 - res = (9.72, 2.0) FAUX


#Liste des scores images 10 : 
    # ((9.72, 2.0), 0.30649545788764954)
    # ((15.87, 11.0), 0.19323967397212982)  #Très interessant -> proche de la réalité
    # ((15.87, 11.0), 0.19323967397212982)
    # ((9.52, 16.0), 0.18065743148326874)
    # ((9.52, 16.0), 0.18065743148326874)
    # ((11.11, 14.0), 0.1788005232810974)
    # ((11.11, 14.0), 0.1788005232810974)

#A voir : rotation

# %%
m,res = main(image_path,reference_object_mm,longueur_cm,depassement_mm)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\PTRANS\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Diamètre'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 m,res = main(image_path,reference_object_mm,longueur_cm,depassement_mm)
#
# Cell In[6], line 2, in main(image_path, reference_object_mm, longueur_cm, depassement_mm)
#       1 def main(image_path,reference_object_mm,longueur_cm,depassement_mm):
# ----> 2     l = pattern_list(pd.read_csv('TableauConversion/Metrique.csv'))
#       3     print(l)
#       4     l_seuil = []
#
# File ~\OneDrive\Bureau\Analysis-of-Industrial-Tool-Images\SRC\list_pas_diam.ipynb:4, in pattern_list(df)
#       1 {
#       2  "cells": [
#       3   {
# ----> 4    "cell_type": "code",
#       5    "execution_count": 8,
#       6    "id": "21aeb656",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import pandas as pd"
#      11    ]
#      12   },
#      13   {
#      14    "cell_type": "code",
#      15    "execution_count": 19,
#      16    "id": "7ed6d19f",
#      17    "metadata": {},
#      18    "outputs": [],
#      19    "source": [
#      20     "df = pd.read_csv('TableauConversion/Metrique.csv')\n",
#      21     "df.columns = ['Type', 'Diamètre', 'Pas']\n"
#      22    ]
#      23   },
#      24   {
#      25    "cell_type": "code",
#      26    "execution_count": 24,
#      27    "id": "294ef65d",
#      28    "metadata": {},
#      29    "outputs": [],
#      30    "source": [
#      31     "def pattern_list(df):\n",
#      32     "    l = []\n",
#      33     "    for index, row in df.iterrows():\n",
#      34     "        metric_str = row['Diamètre']\n",
#      35     "        if pd.notna(metric_str) and \"M\" in metric_str:\n",
#      36     "            try:\n",
#      37     "                diam_mm = float(metric_str.replace(\"M\", \"\").replace(\",\", \".\"))\n",
#      38     "            except ValueError:\n",
#      39     "                continue\n",
#      40     "            pas_value = row['Pas']\n",
#      41     "            if pd.notna(pas_value):\n",
#      42     "                l.append((diam_mm, pas_value/100))\n",
#      43     "    return l\n"
#      44    ]
#      45   },
#      46   {
#      47    "cell_type": "code",
#      48    "execution_count": 25,
#      49    "id": "a683f095",
#      50    "metadata": {},
#      51    "outputs": [
#      52     {
#      53      "data": {
#      54       "text/plain": [
#      55        "0.25"
#      56       ]
#      57      },
#      58      "execution_count": 25,
#      59      "metadata": {},
#      60      "output_type": "execute_result"
#      61     }
#      62    ],
#      63    "source": [
#      64     "l = pattern_list(df)\n",
#      65     "l[0][0]\n",
#      66     "l[0][1]"
#      67    ]
#      68   },
#      69   {
#      70    "cell_type": "code",
#      71    "execution_count": 26,
#      72    "id": "3f557ded",
#      73    "metadata": {},
#      74    "outputs": [
#      75     {
#      76      "name": "stdout",
#      77      "output_type": "stream",
#      78      "text": [
#      79       "Index(['Métrique', 'M1', '25'], dtype='object')\n"
#      80      ]
#      81     }
#      82    ],
#      83    "source": [
#      84     "df = pd.read_csv('TableauConversion/Metrique.csv')\n",
#      85     "print(df.columns)\n"
#      86    ]
#      87   },
#      88   {
#      89    "cell_type": "code",
#      90    "execution_count": null,
#      91    "id": "f8b18d8a",
#      92    "metadata": {},
#      93    "outputs": [],
#      94    "source": []
#      95   }
#      96  ],
#      97  "metadata": {
#      98   "kernelspec": {
#      99    "display_name": "Python 3 (ipykernel)",
#     100    "language": "python",
#     101    "name": "python3"
#     102   },
#     103   "language_info": {
#     104    "codemirror_mode": {
#     105     "name": "ipython",
#     106     "version": 3
#     107    },
#     108    "file_extension": ".py",
#     109    "mimetype": "text/x-python",
#     110    "name": "python",
#     111    "nbconvert_exporter": "python",
#     112    "pygments_lexer": "ipython3",
#     113    "version": "3.11.5"
#     114   }
#     115  },
#     116  "nbformat": 4,
#     117  "nbformat_minor": 5
#     118 }
#
# File ~\anaconda3\envs\PTRANS\Lib\site-packages\pandas\core\series.py:1111, in Series.__getitem__(self, key)
#    1108     return self._values[key]
#    1110 elif key_is_scalar:
# -> 1111     return self._get_value(key)
#    1113 # Convert generator to list before going through hashable part
#    1114 # (We will iterate through the generator there to check for slices)
#    1115 if is_iterator(key):
#
# File ~\anaconda3\envs\PTRANS\Lib\site-packages\pandas\core\series.py:1227, in Series._get_value(self, label, takeable)
#    1224     return self._values[label]
#    1226 # Similar to Index.get_value, but we do not fall back to positional
# -> 1227 loc = self.index.get_loc(label)
#    1229 if is_integer(loc):
#    1230     return self._values[loc]
#
# File ~\anaconda3\envs\PTRANS\Lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'Diamètre'

# %%
print(res)
cv2.imwrite('image.jpg', m)

# %%
p = pattern_list(pd.read_csv('TableauConversion/Tableau_conversion.csv'))
p[0][1] + p[0][0]

# %%
m = main(image_path,reference_object_mm,longueur_cm,depassement_mm)

# %%
cv2.imwrite('image.jpg', m)
